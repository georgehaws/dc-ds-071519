# %% [markdown]
# ![sql](img/sql-logo.jpg)
#
# # A beginner's guide to databases, SQL, & using them with `pandas`

# %% [markdown]
# **Scenario:** You are a data analyst for the Homeland Security, trying to create reports on the active airports world wide. The data you need to access is in a SQL database. YOu need to be able to query for the data in a database!

# %% [markdown]
# ## Learning goals:
# - Goal 1: Summarize the use case for sql in the data science skill set
# - Goal 2: Define key sql terminology
# - Goal 3: Get information about DB schema and table structure
# - Goal 4: Use basic SQL commands:
#     - Construct SQL queries
#     - Use JOIN to merge tables along logical columns
#     - Grouping Data with SQL
# - Goal 5: Query data from pandas dataframes using SQL
# - Goal 6: Convert SQL to pandas

# %% [markdown]
# ## Goal 1: Summarize
#
# [Netflix has a great article](https://medium.com/netflix-techblog/notebook-innovation-591ee3221233) describing three different data roles at their company, their different needs, and their toolsets.
#
# ![netflix](img/netflix-data-roles.jpeg)
#
# Examining that graphic, SQL shows up as one of the tools of the _Data Engineer_

# %% [markdown]
# Data Engineers provide the essential data architecture services that make data science possible.
#
# ![hierarchy](img/ai-hierachy.png)
#
# [Source: Monica Rogati’s fantastic Medium post “The AI Hierarchy of Needs”
# ](https://hackernoon.com/the-ai-hierarchy-of-needs-18f111fcc007)

# %% [markdown]
# ![etl](img/etl.png)
#
# [img source: Jeff Hammerbacher’s slide from UC Berkeley CS 194 course ](https://bcourses.berkeley.edu/courses/1377158/pages/cs-194-16-introduction-to-data-science-fall-2015)

# %% [markdown]
# ### What is a Relational Database?
#
# ![rdb](img/relational-dbms-model.png)
# [reference for image ](https://www.studytonight.com/dbms/database-model.php)

# %% [markdown]
# ### POPULAR RDBMS
#
# - SQLite
# - MySQL
# - PostgreSql
# - Oracle DB
# - SQL Server

# %% [markdown]
# ***
# ## Goal 2: Database terminology
#
# ### Relational Database Schema
#
# ![schema](img/MySQL_Schema_Music_Example.png)
#
# [source of image](https://database.guide/what-is-a-database-schema/)

# %% [markdown]
# ### Table columns view
# ![table example](img/columns.png)

# %% [markdown]
# ### Terminology
#
# - Schema
# - Primary Key
# - Foreign Key
# - Structured queries
# - Views

# %% [markdown]
# ***
# ### SQLite
#
# ![sqlite](img/SQLite-Python.jpg)
#
# "SQLite is a C library that provides a lightweight disk-based database that doesn’t require a separate server process and allows accessing the database using a nonstandard variant of the SQL query language. Some applications can use SQLite for internal data storage. It’s also possible to prototype an application using SQLite and then port the code to a larger database such as PostgreSQL or Oracle." - [sqlite documentation](https://docs.python.org/2/library/sqlite3.html)

# %% [markdown]
# ## But what about connecting to database servers?
#
# To connect to an Oracle database server there is a different package, `cx_Oracle`. The documentation for that package is [here](https://oracle.github.io/python-cx_Oracle/)

# %% [markdown]
# ***
# ## Goal 3: Get going with sqlite!

# %%
import sqlite3
from pprint import pprint

# %% [markdown]
# #### Load a DB object with `connect` and `cursor`

# %%
con = sqlite3.connect('flights.db')
cursor = con.cursor()

# %% [markdown]
# #### Use sqlite_master to find all the tables in the schema
# Get the schema of a database from a db in sqlite

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('airports',), ('airlines',), ('routes',)]

# %% [markdown]
# #### Get information about one table
#
# **A note about** `execute`<br>
# Each time you use it, you reset the value of cursor

# %%
print(cursor.execute("SELECT * FROM airports"))
print(cursor.fetchmany(4))
# Out:
# ...
# [(0, '1', 'Goroka', 'Goroka', 'Papua New Guinea', 'GKA', 'AYGA', '-6.081689', '145.391881', '5282', '10', 'U', 'Pacific/Port_Moresby'), (1, '2', 'Madang', 'Madang', 'Papua New Guinea', 'MAG', 'AYMD', '-5.207083', '145.7887', '20', '10', 'U', 'Pacific/Port_Moresby'), (2, '3', 'Mount Hagen', 'Mount Hagen', 'Papua New Guinea', 'HGU', 'AYMH', '-5.826789', '144.295861', '5388', '10', 'U', 'Pacific/Port_Moresby'), (3, '4', 'Nadzab', 'Nadzab', 'Papua New Guinea', 'LAE', 'AYNZ', '-6.569828', '146.726242', '239', '10', 'U', 'Pacific/Port_Moresby')]

# %% [markdown]
# #### Use description

# %%
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %% [markdown]
# #### Or use `Pragma`
# `Pragma` tool [link here](https://www.sqlite.org/pragma.html#pragma_table_info)
#
# **output**<br>
# `(column id, column name, data type, whether or not the column can be NULL, and the default value for the column)`

# %%
cursor.execute("PRAGMA table_info(airports)")
info = cursor.fetchall()
print(info, sep = " ")
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0), (1, 'id', 'TEXT', 0, None, 0), (2, 'name', 'TEXT', 0, None, 0), (3, 'city', 'TEXT', 0, None, 0), (4, 'country', 'TEXT', 0, None, 0), (5, 'code', 'TEXT', 0, None, 0), (6, 'icao', 'TEXT', 0, None, 0), (7, 'latitude', 'TEXT', 0, None, 0), (8, 'longitude', 'TEXT', 0, None, 0), (9, 'altitude', 'TEXT', 0, None, 0), (10, 'offset', 'TEXT', 0, None, 0), (11, 'dst', 'TEXT', 0, None, 0), (12, 'timezone', 'TEXT', 0, None, 0)]

# %% [markdown]
# #### Making fetch happen
#
# `.fetchall()` is how you get the query results out of the object.
#
# You can also `.fetchone()` or `.fetchmany()`

# %% [markdown]
# **Task:** Get the descriptive data for airlines and routes tables

# %%
cursor.execute("""SELECT * from routes""")

# %%
print(cursor.fetchone())
# Out:
# (0, '2B', '410', 'AER', '2965', 'KZN', '2990', None, '0', 'CR2')

# %% [markdown]
# ***
# ## Goal 4: Use basic SQL commands
# - Construct SQL queries
# - Use JOIN to merge tables along logical columns
# - Grouping Data with SQL

# %% [markdown]
# ### Construct SQL queries

# %% [markdown]
# **Select**

# %% [markdown]
# **From**

# %% [markdown]
# **Where**

# %% [markdown]
# **Order by**

# %% [markdown]
# **Limit**

# %% [markdown]
# #### Options for each:

# %% [markdown]
# **Select**:  `distinct`, using `as` to rename columns, single number aggregates

# %% [markdown]
# **From:** also uses aliasing with `as`

# %% [markdown]
# **Where**: equals is only one `=`, `between`, `in`, wildcards `%`, `AND`, `OR`, `NOT`

# %% [markdown]
# **Order by**: `asc` and `desc`

# %% [markdown]
# **Limit**:  #

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('airports',), ('airlines',), ('routes',)]

# %%
cursor.execute("SELECT * FROM airports")
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %%
cursor.execute("SELECT DISTINCT name FROM airlines WHERE active = 'Y' AND country = 'United Kingdom' ORDER BY name ASC;")
pprint(cursor.fetchmany(50))
# Out:
# [('AD Aviation',),
#  ('Air Cudlua',),
#  ('Air Foyle',),
#  ('Air Southwest',),
#  ('Air Wales',),
#  ('All Europe',),
#  ('Astraeus',),
#  ('Aurigny Air Services',),
#  ('BA CityFlyer',),
#  ('BBN-Airways',),
#  ('British Airways',),
#  ('British International Helicopters',),
#  ('British Mediterranean Airways',),
#  ('British Midland Regional',),
#  ('CB Airways UK ( Interliging Flights )',),
#  ('Crest Aviation',),
#  ('Eastern Airways',),
#  ('Excel Airways',),
#  ('Excel Charter',),
#  ('First Choice Airways',),
#  ('Flightline',),
#  ('Flybe',),
#  ('Flyglobespan',),
#  ('GB Airways',),
#  ('Highland Airways',),
#  ('Jc royal.britannica',),
#  ('Jet2.com',),
#  ('Kinloss Flying Training Unit',),
#  ('Monarch Airlines',),
#  ('MyTravel Airways',),
#  ('Norfolk County Flight College',),
#  ('Rainbow Air Euro',),
#  ('Royal European Airlines',),
#  ('ScotAirways',),
#  ('Thomas Cook Airlines',),
#  ('Thomsonfly',),
#  ('Virgin Atlantic Airways',),
#  ('bmi',),
#  ('bmibaby',),
# ...

# %% [markdown]
# **Task**:
# - Select only active airlines in the UK from the airlines table
# - Select the unique list of countries with airports

# %%
cursor.execute("SELECT DISTINCT country FROM airports ORDER BY country ASC")
pprint(cursor.fetchmany(40))
# Out:
# [('Afghanistan',),
#  ('Albania',),
#  ('Algeria',),
#  ('American Samoa',),
#  ('Angola',),
#  ('Anguilla',),
#  ('Antarctica',),
#  ('Antigua and Barbuda',),
#  ('Argentina',),
#  ('Armenia',),
#  ('Aruba',),
#  ('Australia',),
#  ('Austria',),
#  ('Azerbaijan',),
#  ('Bahamas',),
#  ('Bahrain',),
#  ('Bangladesh',),
#  ('Barbados',),
#  ('Belarus',),
#  ('Belgium',),
#  ('Belize',),
#  ('Benin',),
#  ('Bermuda',),
#  ('Bhutan',),
#  ('Bolivia',),
#  ('Bosnia and Herzegovina',),
#  ('Botswana',),
#  ('Brazil',),
#  ('British Indian Ocean Territory',),
#  ('British Virgin Islands',),
#  ('Brunei',),
#  ('Bulgaria',),
#  ('Burkina Faso',),
#  ('Burma',),
#  ('Burundi',),
#  ('Cambodia',),
#  ('Cameroon',),
#  ('Canada',),
#  ('Cape Verde',),
#  ('Cayman Islands',)]

# %% [markdown]
# ### SQL Joins

# %% [markdown]
# SQL joins can be used to both **add** data to a table and **remove** data from a table.

# %% [markdown]
# ![venn](img/venn.png)

# %% [markdown]
# **Task** Write a query that will join the latitude and longitude data from the airports table to the information on the routes table

# %%
cursor.execute("SELECT * FROM airports")
print(cursor.fetchmany(10))
# Out:
# [(0, '1', 'Goroka', 'Goroka', 'Papua New Guinea', 'GKA', 'AYGA', '-6.081689', '145.391881', '5282', '10', 'U', 'Pacific/Port_Moresby'), (1, '2', 'Madang', 'Madang', 'Papua New Guinea', 'MAG', 'AYMD', '-5.207083', '145.7887', '20', '10', 'U', 'Pacific/Port_Moresby'), (2, '3', 'Mount Hagen', 'Mount Hagen', 'Papua New Guinea', 'HGU', 'AYMH', '-5.826789', '144.295861', '5388', '10', 'U', 'Pacific/Port_Moresby'), (3, '4', 'Nadzab', 'Nadzab', 'Papua New Guinea', 'LAE', 'AYNZ', '-6.569828', '146.726242', '239', '10', 'U', 'Pacific/Port_Moresby'), (4, '5', 'Port Moresby Jacksons Intl', 'Port Moresby', 'Papua New Guinea', 'POM', 'AYPY', '-9.443383', '147.22005', '146', '10', 'U', 'Pacific/Port_Moresby'), (5, '6', 'Wewak Intl', 'Wewak', 'Papua New Guinea', 'WWK', 'AYWK', '-3.583828', '143.669186', '19', '10', 'U', 'Pacific/Port_Moresby'), (6, '7', 'Narsarsuaq', 'Narssarssuaq', 'Greenland', 'UAK', 'BGBW', '61.160517', '-45.425978', '112', '-3', 'E', 'America/Godthab'), (7, '8', 'Nuuk', 'Godthaa
# ...

# %%
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %%
cursor.execute("SELECT * FROM airports")
cursor.fetchmany(10)
# Out:
# [(0,
#   '1',
#   'Goroka',
#   'Goroka',
#   'Papua New Guinea',
#   'GKA',
#   'AYGA',
#   '-6.081689',
#   '145.391881',
#   '5282',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (1,
#   '2',
#   'Madang',
#   'Madang',
#   'Papua New Guinea',
#   'MAG',
#   'AYMD',
#   '-5.207083',
#   '145.7887',
#   '20',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (2,
#   '3',
#   'Mount Hagen',
#   'Mount Hagen',
#   'Papua New Guinea',
#   'HGU',
#   'AYMH',
#   '-5.826789',
#   '144.295861',
#   '5388',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (3,
#   '4',
#   'Nadzab',
#   'Nadzab',
#   'Papua New Guinea',
#   'LAE',
#   'AYNZ',
#   '-6.569828',
#   '146.726242',
#   '239',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (4,
#   '5',
#   'Port Moresby Jacksons Intl',
#   'Port Moresby',
#   'Papua New Guinea',
#   'POM',
#   'AYPY',
#   '-9.443383',
#   '147.22005',
#   '146',
#   '10',
#   'U',
#   'Pacific/Port_Moresby'),
#  (5,
#   '6',
#   'Wewak Intl',
# ...

# %%
cursor.description
# Out:
# (('index', None, None, None, None, None, None),
#  ('id', None, None, None, None, None, None),
#  ('name', None, None, None, None, None, None),
#  ('city', None, None, None, None, None, None),
#  ('country', None, None, None, None, None, None),
#  ('code', None, None, None, None, None, None),
#  ('icao', None, None, None, None, None, None),
#  ('latitude', None, None, None, None, None, None),
#  ('longitude', None, None, None, None, None, None),
#  ('altitude', None, None, None, None, None, None),
#  ('offset', None, None, None, None, None, None),
#  ('dst', None, None, None, None, None, None),
#  ('timezone', None, None, None, None, None, None))

# %%
cursor.execute("SELECT name, latitude, longitude FROM airports INNER JOIN routes ON code = source ORDER BY name ASC")
pprint(cursor.fetchmany(20))
# Out:
# [('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('A Coruna', '43.302061', '-8.377256'),
#  ('Aalborg', '57.092789', '9.849164'),
#  ('Aalborg', '57.092789', '9.849164'),
#  ('Aalborg', '57.092789', '9.849164'),
#  ('Aalborg', '57.092789', '9.849164'),
#  ('Aalborg', '57.092789', '9.849164'),
#  ('Aalborg', '57.092789', '9.849164'),
#  ('Aalborg', '57.092789', '9.849164'),
#  ('Aalborg', '57.092789', '9.849164')]

# %% [markdown]
# ### Grouping statements
#
# Combines `select` and `group by` when you want aggregates by values

# %% [markdown]
# `select` `min(x)` ... `max()`, `sum()`, etc

# %% [markdown]
# `group by x`

# %% [markdown]
# **Task**<br>
# - Which countries have the highest amount of active airports?
# - Which countries have the highest amount of inactive airports?
# - What about airports by timezones?

# %%
cursor.execute("SELECT country, COUNT(name) FROM airlines WHERE active = 'Y' GROUP BY country ORDER BY COUNT(name) DESC;")
pprint(cursor.fetchmany(10))
# Out:
# [('United States', 141),
#  ('Russia', 72),
#  ('United Kingdom', 40),
#  ('Germany', 37),
#  ('Canada', 34),
#  ('Australia', 26),
#  ('China', 25),
#  ('Spain', 24),
#  ('Brazil', 23),
#  ('France', 22)]

# %%
cursor.execute("SELECT country, COUNT(name) FROM airlines WHERE active = 'N' GROUP BY country ORDER BY COUNT(name) DESC;")
pprint(cursor.fetchmany(10))
# Out:
# [('United States', 939),
#  ('Mexico', 427),
#  ('United Kingdom', 367),
#  ('Canada', 284),
#  ('Russia', 158),
#  ('Spain', 142),
#  ('France', 97),
#  ('Germany', 94),
#  ('South Africa', 81),
#  ('Nigeria', 80)]

# %%
cursor.execute("SELECT timezone, COUNT(ID) FROM airports GROUP BY timezone ORDER BY COUNT(ID) DESC;")
pprint(cursor.fetchmany(10))
# Out:
# [('America/New_York', 628),
#  ('America/Chicago', 373),
#  ('Europe/Berlin', 319),
#  ('America/Anchorage', 258),
#  ('Europe/Paris', 232),
#  ('America/Los_Angeles', 226),
#  ('Asia/Chongqing', 222),
#  ('Europe/London', 193),
#  ('America/Toronto', 159),
#  ('Asia/Calcutta', 141)]

# %% [markdown]
# ## Goal 5: Using sql within pandas to filter
#
# `.query()`
#
# [query documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html)

# %%
# Get data for an example
import pandas as pd
shelter_data=pd.read_csv('https://data.austintexas.gov/api/views/9t4d-g238/rows.csv?accessType=DOWNLOAD')
shelter_data.dtypes
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# MonthYear           object
# Date of Birth       object
# Outcome Type        object
# Outcome Subtype     object
# Animal Type         object
# Sex upon Outcome    object
# Age upon Outcome    object
# Breed               object
# Color               object
# dtype: object

# %%
max_data = shelter_data.query('Name == "Max"')
max_data.head()
# Out:
#      Animal ID Name                DateTime               MonthYear  \
# 24     A800872  Max  08/01/2019 04:37:00 PM  08/01/2019 04:37:00 PM
# 179    A800791  Max  07/29/2019 06:07:00 PM  07/29/2019 06:07:00 PM
# 314    A788916  Max  07/27/2019 05:16:00 PM  07/27/2019 05:16:00 PM
# 342    A799870  Max  07/26/2019 07:17:00 PM  07/26/2019 07:17:00 PM
# 1222   A799881  Max  07/13/2019 02:33:00 PM  07/13/2019 02:33:00 PM
#
#      Date of Birth     Outcome Type Outcome Subtype Animal Type  \
# 24      06/12/2019         Adoption             NaN         Dog
# 179     07/26/2017  Return to Owner             NaN         Dog
# 314     11/26/2018  Return to Owner             NaN         Dog
# 342     07/13/2017  Return to Owner             NaN         Dog
# 1222    05/13/2019         Transfer         Partner         Dog
#
#      Sex upon Outcome Age upon Outcome                  Breed  \
# 24      Neutered Male          1 month    German Shepherd Mix
# ...

# %%
shelter_data[shelter_data['Name']=="Max"]
# Out:
#        Animal ID Name                DateTime               MonthYear  \
# 24       A800872  Max  08/01/2019 04:37:00 PM  08/01/2019 04:37:00 PM
# 179      A800791  Max  07/29/2019 06:07:00 PM  07/29/2019 06:07:00 PM
# 314      A788916  Max  07/27/2019 05:16:00 PM  07/27/2019 05:16:00 PM
# 342      A799870  Max  07/26/2019 07:17:00 PM  07/26/2019 07:17:00 PM
# 1222     A799881  Max  07/13/2019 02:33:00 PM  07/13/2019 02:33:00 PM
# 1587     A798950  Max  07/07/2019 01:31:00 PM  07/07/2019 01:31:00 PM
# 1736     A799025  Max  07/05/2019 11:13:00 AM  07/05/2019 11:13:00 AM
# 2016     A798743  Max  06/30/2019 04:54:00 PM  06/30/2019 04:54:00 PM
# 2471     A700767  Max  06/25/2019 02:12:00 PM  06/25/2019 02:12:00 PM
# 2781     A797355  Max  06/21/2019 06:39:00 PM  06/21/2019 06:39:00 PM
# 2793     A797407  Max  06/21/2019 04:05:00 PM  06/21/2019 04:05:00 PM
# 2949     A797258  Max  06/19/2019 12:58:00 PM  06/19/2019 12:58:00 PM
# ...

# %%
shelter_data.rename(index=str, columns={"Animal Type": "animal_type"}, inplace = True)
test = shelter_data.query('animal_type == "Dog"')
test.head()
# Out:
#    Animal ID    Name                DateTime               MonthYear  \
# 2    A800494   Ducky  08/01/2019 07:27:00 PM  08/01/2019 07:27:00 PM
# 4    A800251    Kobe  08/01/2019 07:00:00 PM  08/01/2019 07:00:00 PM
# 5    A800913     NaN  08/01/2019 06:42:00 PM  08/01/2019 06:42:00 PM
# 6    A800911  Sawyer  08/01/2019 06:32:00 PM  08/01/2019 06:32:00 PM
# 10   A800614     NaN  08/01/2019 06:31:00 PM  08/01/2019 06:31:00 PM
#
#    Date of Birth     Outcome Type Outcome Subtype animal_type  \
# 2     10/22/2018         Adoption             NaN         Dog
# 4     01/18/2017  Return to Owner             NaN         Dog
# 5     06/09/2019         Adoption             NaN         Dog
# 6     06/09/2019         Adoption             NaN         Dog
# 10    03/24/2019         Adoption             NaN         Dog
#
#    Sex upon Outcome Age upon Outcome            Breed            Color
# 2     Spayed Female         9 months      Whippet Mix      Black/White
# ...

# %% [markdown]
# ## Goal 6: Transfering from sqlite to pandas

# %%
conn = sqlite3.connect("flights.db")
df = pd.read_sql_query("SELECT * FROM airports;", conn)
df
# Out:
#       index    id                               name                city  \
# 0         0     1                             Goroka              Goroka
# 1         1     2                             Madang              Madang
# 2         2     3                        Mount Hagen         Mount Hagen
# 3         3     4                             Nadzab              Nadzab
# 4         4     5         Port Moresby Jacksons Intl        Port Moresby
# 5         5     6                         Wewak Intl               Wewak
# 6         6     7                         Narsarsuaq        Narssarssuaq
# 7         7     8                               Nuuk            Godthaab
# 8         8     9                  Sondre Stromfjord         Sondrestrom
# 9         9    10                     Thule Air Base               Thule
# 10       10    11                           Akureyri            Akureyri
# 11       11    12                        Egilsstadir         Egilsstadir
# ...

# %% [markdown]
# **Task**:
# Convert one of the earlier queries in the lesson to a pandas data frame

# %% [markdown]
# ## Integration
#
# The [Chinook database](https://github.com/lerocha/chinook-database) is a sample database, representing a digital media store.
#
# ###### You need to create a query that can rank tracks in terms of popularity.
#
# The name of the database is `Chinook_Sqlite.sqlite`

# %% [markdown]
# Database information:<br>
# - How many tables are in the database?
# - What's the primary key of each table?
# - What foreign keys join the tables together?
# - If you had to draw a schema of how the tables are connected, what would it look like?

# %% [markdown]
# To answer the question:<br>
# - What are the max and min dates in the Invoice table?
# - What tables would you need to answer "what is your most popular track?"
# - What values from each table?

# %%
con = sqlite3.connect('Chinook_Sqlite.sqlite')
cursor = con.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master;")
cursor.fetchall()
# Out:
# [('Album',),
#  ('Artist',),
#  ('Customer',),
#  ('Employee',),
#  ('Genre',),
#  ('Invoice',),
#  ('InvoiceLine',),
#  ('MediaType',),
#  ('Playlist',),
#  ('PlaylistTrack',),
#  ('sqlite_autoindex_PlaylistTrack_1',),
#  ('Track',),
#  ('IPK_Album',),
#  ('IPK_Artist',),
#  ('IPK_Customer',),
#  ('IPK_Employee',),
#  ('IPK_Genre',),
#  ('IPK_Invoice',),
#  ('IPK_InvoiceLine',),
#  ('IPK_MediaType',),
#  ('IPK_Playlist',),
#  ('IPK_PlaylistTrack',),
#  ('IPK_Track',),
#  ('IFK_AlbumArtistId',),
#  ('IFK_CustomerSupportRepId',),
#  ('IFK_EmployeeReportsTo',),
#  ('IFK_InvoiceCustomerId',),
#  ('IFK_InvoiceLineInvoiceId',),
#  ('IFK_InvoiceLineTrackId',),
#  ('IFK_PlaylistTrackTrackId',),
#  ('IFK_TrackAlbumId',),
#  ('IFK_TrackGenreId',),
#  ('IFK_TrackMediaTypeId',)]

# %%
cursor.execute("SELECT * FROM PlaylistTrack;")
cursor.description
# Out:
# (('PlaylistId', None, None, None, None, None, None),
#  ('TrackId', None, None, None, None, None, None))

# %%
cursor.execute("SELECT MAX(InvoiceDate) FROM INVOICE")
cursor.fetchall()
# Out:
# [('2013-12-22 00:00:00',)]

# %%
cursor.execute("SELECT MIN(InvoiceDate) FROM INVOICE")
cursor.fetchall()
# Out:
# [('2009-01-01 00:00:00',)]

# %%
cursor.execute("SELECT COUNT(InvoiceLineID) FROM InvoiceLine LEFT JOIN Track ON TrackID GROUP BY TrackID;")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-78-3a255a5949e9> in <module>
# ----> 1 cursor.execute("SELECT COUNT(InvoiceLineID) FROM InvoiceLine LEFT JOIN Track ON TrackID GROUP BY TrackID;")
#
# OperationalError: ambiguous column name: TrackID

# %% [markdown]
# ## Reflection
